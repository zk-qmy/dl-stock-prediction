# %%
# !pip install matplotlib seaborn numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 7.8/7.8 MB 2.6 MB/s eta 0:00:00
# ...
#      -------------------------------------- 294.9/294.9 kB 2.6 MB/s eta 0:00:00
# ...
#      -------------------------------------- 217.2/217.2 kB 3.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.2/2.2 MB 2.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 56.0/56.0 kB 1.5 MB/s eta 0:00:00
# ...
#      -------------------------------------- 104.1/104.1 kB 1.2 MB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'..\data\toprocess\nasdag_chosen.csv')
df
# Out:
#              Date Ticker  Low  Open  Volume  High  Close  AdjustedClose
# 0      1980-03-17   AAME  4.0   0.0   15000   4.0    4.0            4.0
# 1      1980-03-18   AAME  4.0   0.0   10250   4.0    4.0            3.0
# 2      1980-03-19   AAME  4.0   0.0   33500   4.0    4.0            4.0
# 3      1980-03-20   AAME  4.0   0.0    8750   4.0    4.0            3.0
# 4      1980-03-21   AAME  4.0   0.0   12750   4.0    4.0            3.0
# ...           ...    ...  ...   ...     ...   ...    ...            ...
# 10773  2022-12-06   AAME  3.0   3.0    2700   3.0    3.0            3.0
# 10774  2022-12-07   AAME  3.0   3.0     700   3.0    3.0            3.0
# 10775  2022-12-08   AAME  3.0   3.0   13800   3.0    3.0            3.0
# 10776  2022-12-09   AAME  3.0   3.0    3600   3.0    3.0            3.0
# 10777  2022-12-12   AAME  3.0   3.0     808   3.0    3.0            3.0
#
# [10778 rows x 8 columns]

# %%
data = df.copy()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10778 entries, 0 to 10777
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           10778 non-null  object
#  1   Ticker         10778 non-null  object
#  2   Low            10778 non-null  float64
#  3   Open           10778 non-null  float64
#  4   Volume         10778 non-null  int64
#  5   High           10778 non-null  float64
#  6   Close          10778 non-null  float64
#  7   AdjustedClose  10778 non-null  float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 673.8+ KB

# %%
data.describe()
# Out:
#                 Low          Open        Volume          High         Close  \
# count  10778.000000  10778.000000  1.077800e+04  10778.000000  10778.000000
# mean       3.516051      2.543793  2.430651e+04      3.632307      3.573854
# std        2.289434      1.771587  1.100144e+06      2.343512      2.304179
# min        0.000000      0.000000  0.000000e+00      0.000000      0.000000
# 25%        2.000000      2.000000  1.100000e+03      2.000000      2.000000
# 50%        3.000000      2.000000  3.500000e+03      3.000000      3.000000
# 75%        4.000000      3.000000  9.500000e+03      4.000000      4.000000
# max       15.000000     14.000000  1.119128e+08     16.000000     16.000000
#
#        AdjustedClose
# count   10778.000000
# mean        3.323437
# std         2.110049
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        14.000000

# %%
data.shape
# Out:
# (10778, 8)

# %%
# Count of null values in each column
print("\nCount of nan values in each column:")
print(data.isna().sum())  # or data.isnull().sum()
# Out:
# Count of null values in each column:
# Date             0
# Ticker           0
# Low              0
# Open             0
# Volume           0
# High             0
# Close            0
# AdjustedClose    0
# dtype: int64
#
# Count of nan values in each column:
# Date             0
# Ticker           0
# Low              0
# Open             0
# Volume           0
# High             0
# Close            0
# AdjustedClose    0
# dtype: int64

# %%
# Visualize the time series
sns.set(style="whitegrid")  # Setting the style to whitegrid for a clean background
 
plt.figure(figsize=(12, 6))  # Setting the figure size
sns.lineplot(data, x='Date', y='High', label='High Price', color='blue')
 
# Adding labels and title
plt.xlabel('Date')
plt.ylabel('High')
plt.title('Share Highest Price Over Time')
 
plt.show()
